# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Reading And Analysing the Dataset

# %%
df=pd.read_csv(r"C:\Users\Avinash\Desktop\Projects\EvaluationProjects\2_Baseball\baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no missing values in our dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
df=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)

# %%
df.head()
# Out:
#           W         R        AB         H        2B        3B        HR  \
# 0  0.864865  0.474843  0.719697  0.905759  0.888889  0.805556  0.295455
# 1  0.540541  0.386792  0.310606  0.130890  0.569444  0.861111  0.424242
# 2  0.486486  0.301887  0.204545  0.371728  0.930556  0.444444  0.310606
# 3  0.351351  0.154088  0.560606  0.298429  0.333333  0.388889  0.272727
# 4  0.297297  0.364780  0.833333  1.000000  0.736111  1.000000  0.386364
#
#          BB        SO        SB        RA        ER       ERA        CG  \
# 0  0.041026  0.000000  0.666667  0.363636  0.383178  0.376190  0.181818
# 1  0.328205  0.533945  0.288889  0.548589  0.545171  0.538095  0.181818
# 2  0.810256  0.337615  0.466667  0.360502  0.330218  0.347619  1.000000
# 3  0.148718  0.473394  0.266667  0.551724  0.514019  0.495238  0.636364
# 4  0.410256  0.524771  0.433333  0.871473  0.834891  0.809524  0.636364
#
#         SHO        SV         E
# 0  0.235294  0.823529  0.254902
# 1  0.470588  0.500000  0.215686
# ...

# %% [markdown]
# ## Uni_Variant Analysis

# %% [markdown]
# ### Distplot

# %%
for column in df:
        plt.figure(figsize=(5,5))
        sn.distplot(df[column])

# %% [markdown]
# Some Skewness is there in various columns which we will handle later.

# %% [markdown]
# ### Boxplot

# %%
for column in df:
        plt.figure(figsize=(8,4))
        sn.boxplot(x=column,data=df)

# %% [markdown]
# Do not have much outliers but E have a few outliers which we will deal with later.

# %% [markdown]
# ## BI_Variant Analysis

# %% [markdown]
# ### Pairplot

# %%
sn.pairplot(data=df,
            x_vars=['W'],
            y_vars=df.columns)

# %% [markdown]
# RA ER ERA SV haeve a kind of linear relationship between them.

# %% [markdown]
# ### Heatmap

# %%
plt.figure(figsize=(14,10))
sn.heatmap(df.corr(),linewidths=.1,cmap="coolwarm", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# AB,H,SO,SB,CG are not highly positively or negetively correlated to each other.

# %% [markdown]
# Also ERA,ER is highly Correlated to Ra so we have to drop RA for bette rperformance.Also H and AB have high correlation do we drop both as both of them have almost zero correlation with our target variable.

# %%
df=df.drop(columns={"RA","AB","H"})

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
df=df[(z<3).all(axis=1)]
df.shape
# Out:
# (29, 14)

# %% [markdown]
# Less than one percent data is lost so outlier removal is successful.

# %% [markdown]
# # Skewness Removal

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# 3 columns need to be treated

# %% [markdown]
# ### CG

# %%
cg=np.sqrt(df["CG"])
cg.skew()
# Out:
# -0.2606778075812137

# %%
df["CG"]=cg

# %% [markdown]
# ### SV

# %%
sv=np.log10(df["SV"]+1)
sv.skew()
# Out:
# 0.16693549504612717

# %%
df["SV"]=sv

# %% [markdown]
# ### E

# %%
e=np.sqrt(df["E"])
e.skew()
# Out:
# -0.20656213405869617

# %%
df["E"]=e

# %% [markdown]
# # Input Splitting

# %%
x=df.drop(["W"],axis=1)

# %%
y=df["W"]

# %% [markdown]
# # Finding The Best Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
#regress function
from sklearn.model_selection import cross_val_score,train_test_split
def regress(model,x,y):
    X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.25,random_state=7)
    #train the model
    model.fit(X_train,Y_train)
    ac=model.score(X_test,Y_test)*100
    print("R2:",ac)
    
    #cross validation
    score=cross_val_score(model,x,y,cv=5)
    cv=np.mean(score)*100
    print("CV Score:",cv)
    
    #diffrence between them
    print("Diffrence:",abs(ac-cv))

# %%
LR=LinearRegression()
regress(LR,x,y)
# Out:
# R2: 33.12999515641681
# CV Score: 38.84917142078068
# Diffrence: 5.719176264363867

# %%
DTR = DecisionTreeRegressor()
regress(DTR,x,y)
# Out:
# R2: 33.904853435848125
# CV Score: -190.82314780161025
# Diffrence: 224.7280012374584

# %%
RDG=Ridge()
regress(RDG,x,y)
# Out:
# R2: 40.32857836002207
# CV Score: 6.451658030575405
# Diffrence: 33.87692032944666

# %%
LSO=Lasso()
regress(LSO,x,y)
# Out:
# R2: -0.8708921338838271
# CV Score: -38.84940924358675
# Diffrence: 37.97851710970292

# %%
RFR=RandomForestRegressor()
regress(RFR,x,y)
# Out:
# R2: 39.70396040365196
# CV Score: -48.6373624039641
# Diffrence: 88.34132280761605

# %%
KNR=KNeighborsRegressor()
regress(KNR,x,y)
# Out:
# R2: 34.43090821720326
# CV Score: -74.30959329411925
# Diffrence: 108.74050151132252

# %%
XGB=XGBRegressor()
regress(XGB,x,y)
# Out:
# R2: 31.429885923293234
# CV Score: -137.5246969158672
# Diffrence: 168.95458283916042

# %% [markdown]
# Linear Regression is our Best Model

# %% [markdown]
# # Hyper Parameter Tuning

# %%
LR.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': False,
#  'positive': False}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {'copy_X': [True,False],
 'fit_intercept': [True,False],
 'n_jobs': [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
 'normalize': [True,False],
 'positive': [True,False]}

# %%
rf_random = RandomizedSearchCV(estimator = LR, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.25,random_state=7)
rf_random.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=LinearRegression(), n_iter=100, n_jobs=-1,
#                    param_distributions={'copy_X': [True, False],
#                                         'fit_intercept': [True, False],
#                                         'n_jobs': [200, 400, 600, 800, 1000,
#                                                    1200, 1400, 1600, 1800,
#                                                    2000],
#                                         'normalize': [True, False],
#                                         'positive': [True, False]},
#                    random_state=42, verbose=2)

# %%
rf_random.best_params_
# Out:
# {'positive': False,
#  'normalize': True,
#  'n_jobs': 1200,
#  'fit_intercept': False,
#  'copy_X': False}

# %% [markdown]
# ## Checking Accuracy Score

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
LR_New=LinearRegression(positive= False,
 normalize= True,
 n_jobs= 1200,
 fit_intercept= False,
copy_X=False)

# %%
LR_New.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=False, fit_intercept=False, n_jobs=1200, normalize=True)

# %%
LR_New.score(X_test,Y_test)
# Out:
# 0.2229933594360427

# %%
y_test_pred=LR_New.predict(X_test)

# %%
print(LR_New.score(X_test, y_test_pred))
# Out:
# 1.0

# %% [markdown]
# # Finally Saving our model

# %%
import joblib
joblib.dump(LR_New,r"C:\Users\Avinash\Desktop\Projects\EvaluationProjects\2_Baseball\win.pkl")
# Out:
# ['C:\\Users\\Avinash\\Desktop\\Projects\\EvaluationProjects\\2_Baseball\\win.pkl']
